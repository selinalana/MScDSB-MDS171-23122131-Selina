# %%
class expenseTracker:

    def __init__(self):
        self.expenseDict = {
            "income": [],
            "expense": [],
        }

    def store_transactions(self, type, amt, category, date, details):
        trans = {
            "Amount": amt,
            "Category": category,
            "Date": date,
            "Details": details,
        }
        if type == "income":
            self.expenseDict['income'].append(trans)
        else:
            self.expenseDict['expense'].append(trans)

    def view_transactions(self):
        print("Your Income:")
        for item in self.expenseDict['income']:
            print(item)
        print("Your Expenses:")
        for item in self.expenseDict['expense']:
            print(item)

    def calculate_transactions(self):
        total_income = 0
        for item in self.expenseDict['income']:
            total_income += item["Amount"]
        print("Total Income\t:\t", total_income)

        total_expense = 0
        for item in self.expenseDict['expense']:
            total_expense += item["Amount"]
        print("Total Expenses\t:\t", total_expense)

    def export_to_file(self):
        with open('selina.csv', 'w+') as file:
            file.write("Income Transactions:\n")
            for item in self.expenseDict['income']:
                file.write(str(item)+ "\n")
            file.write("\nExpense Transactions:\n")
            for item in self.expenseDict['expense']:
                file.write(str(item) + "\n")
            print("Exported to file successfully")

# define a menu that will let users to enter expense, view expenses
# or income, get totals in each and exit from the program


def collectInput():
    amt = int(input("Enter the amout: "))
    category = input("Enter Category: ")
    date = input("Enter Date (DD/MM/YYYY): ")
    details = input("Enter description: ")
    return amt, category, date, details


myexpense = expenseTracker()

while True:
    print("...MY EXPENSE TRACKER...")
    print("1. Record Income")
    print("2. Record Expense")
    print("3. View Records")
    print("4. View My Spendings")
    print("5. Export to file")
    print("6. Exit")

    choice = int(input("Enter your choice: ").strip())

    if choice == 1:
        print("Enter the details of income")
        amt, category, date, details = collectInput()
        myexpense.store_transactions("income", amt, category, date, details)
    elif choice == 2:
        print("Enter the details of expense")
        amt, category, date, details = collectInput()
        myexpense.store_transactions("expense", amt, category, date, details)
    elif choice == 3:
        myexpense.view_transactions()
    elif choice == 4:
        myexpense.calculate_transactions()
    elif choice == 5:
        myexpense.export_to_file()
    elif choice == 6:
        break
    else:
        print("In valid choice")
# Out:
# ...MY EXPENSE TRACKER...
# 1. Record Income
# 2. Record Expense
# 3. View Records
# 4. View My Spendings
# 5. Export to file
# 6. Exit
# Enter the details of income
# ...MY EXPENSE TRACKER...
# 1. Record Income
# 2. Record Expense
# 3. View Records
# 4. View My Spendings
# 5. Export to file
# 6. Exit
# Enter the details of expense
# ...MY EXPENSE TRACKER...
# 1. Record Income
# 2. Record Expense
# 3. View Records
# 4. View My Spendings
# 5. Export to file
# 6. Exit
# Enter the details of expense
# ...MY EXPENSE TRACKER...
# 1. Record Income
# 2. Record Expense
# 3. View Records
# 4. View My Spendings
# 5. Export to file
# 6. Exit
# Enter the details of expense
# ...MY EXPENSE TRACKER...
# 1. Record Income
# 2. Record Expense
# 3. View Records
# 4. View My Spendings
# 5. Export to file
# 6. Exit
# Enter the details of expense
# ...MY EXPENSE TRACKER...
# 1. Record Income
# 2. Record Expense
# 3. View Records
# 4. View My Spendings
# 5. Export to file
# 6. Exit
# Enter the details of expense
# ...MY EXPENSE TRACKER...
# 1. Record Income
# 2. Record Expense
# 3. View Records
# 4. View My Spendings
# 5. Export to file
# 6. Exit
# Enter the details of expense
# ...MY EXPENSE TRACKER...
# 1. Record Income
# 2. Record Expense
# 3. View Records
# 4. View My Spendings
# 5. Export to file
# 6. Exit
# Enter the details of expense
# ...MY EXPENSE TRACKER...
# 1. Record Income
# 2. Record Expense
# 3. View Records
# 4. View My Spendings
# 5. Export to file
# 6. Exit
# Enter the details of expense
# ...MY EXPENSE TRACKER...
# 1. Record Income
# 2. Record Expense
# 3. View Records
# 4. View My Spendings
# 5. Export to file
# 6. Exit
# Enter the details of expense
# ...MY EXPENSE TRACKER...
# 1. Record Income
# 2. Record Expense
# 3. View Records
# 4. View My Spendings
# 5. Export to file
# 6. Exit
# Enter the details of expense
# ...MY EXPENSE TRACKER...
# 1. Record Income
# 2. Record Expense
# 3. View Records
# 4. View My Spendings
# 5. Export to file
# 6. Exit
# Your Income:
# {'Amount': 100000, 'Category': 'salary', 'Date': '10/08/23', 'Details': 'monthly salary'}
# Your Expenses:
# {'Amount': 15000, 'Category': '', 'Date': '10/09/23', 'Details': 'housing'}
# {'Amount': 9000, 'Category': 'food', 'Date': '15/09/23', 'Details': 'fooding'}
# {'Amount': 9000, 'Category': 'shopping', 'Date': '17/09/23', 'Details': 'clothes'}
# {'Amount': 4000, 'Category': 'entertainment', 'Date': '16/09/23', 'Details': 'movies'}
# {'Amount': 5000, 'Category': 'grocery', 'Date': '17/09/23', 'Details': 'groceries'}
# {'Amount': 9000, 'Category': 'transportation', 'Date': '19/09/23', 'Details': 'convience'}
# {'Amount': 9000, 'Category': 'waterbill', 'Date': '19/09/23', 'Details': 'water'}
# {'Amount': 7000, 'Category': 'tax', 'Date': '16/00/23', 'Details': 'GST'}
# {'Amount': 8000, 'Category': 'miscellaneous', 'Date': '20/09/23', 'Details': 'extra'}
# {'Amount': 5000, 'Category': 'grooming', 'Date': '17/09/23', 'Details': 'parlour'}
# ...MY EXPENSE TRACKER...
# 1. Record Income
# 2. Record Expense
# 3. View Records
# 4. View My Spendings
# 5. Export to file
# 6. Exit
# Total Income	:	 100000
# Total Expenses	:	 80000
# ...MY EXPENSE TRACKER...
# 1. Record Income
# 2. Record Expense
# 3. View Records
# 4. View My Spendings
# 5. Export to file
# 6. Exit
# Exported to file successfully
# ...MY EXPENSE TRACKER...
# 1. Record Income
# 2. Record Expense
# 3. View Records
# 4. View My Spendings
# 5. Export to file
# 6. Exit
# Exported to file successfully
# ...MY EXPENSE TRACKER...
# 1. Record Income
# 2. Record Expense
# 3. View Records
# 4. View My Spendings
# 5. Export to file
# 6. Exit
