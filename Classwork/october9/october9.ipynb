# %% [markdown]
# Pandas

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd #pd is a variable name for importing pandas

# %%
pd.read_csv("23122131.csv")
# Out:
#         Shoes  20   7900
# 0         Tie   9  15000
# 1        Tops  30   6500
# 2       Dress  10  15000
# 3       Dress  17   9000
# 4   Swimsuits  25  17500
# ..        ...  ..    ...
# 94   Jumpsuit  10  17500
# 95        Tie   9   5000
# 96  Swimsuits  12   8500
# 97      Saree  20   8500
# 98        Tie  22  12200
#
# [99 rows x 3 columns]

# %%
df= pd.read_csv("23122131.csv")

# %%
df.head()
# Out:
#        Shoes  20   7900
# 0        Tie   9  15000
# 1       Tops  30   6500
# 2      Dress  10  15000
# 3      Dress  17   9000
# 4  Swimsuits  25  17500

# %%
df.tail()
# Out:
#         Shoes  20   7900
# 94   Jumpsuit  10  17500
# 95        Tie   9   5000
# 96  Swimsuits  12   8500
# 97      Saree  20   8500
# 98        Tie  22  12200

# %%
df.head(9)    #df is data frame
# Out:
#        Shoes  20   7900
# 0        Tie   9  15000
# 1       Tops  30   6500
# 2      Dress  10  15000
# 3      Dress  17   9000
# 4  Swimsuits  25  17500
# 5      Saree  22  15000
# 6      Dress  12   4500
# 7      Shoes  15   5000
# 8      Dress  20   1200

# %%
#create a class pandas_Name that will help youo to read a csv file and print the top/bottom n rows in the file

class pandas_Name:
        init()
                #stores the data
        read_csv()
                #reads a csv file
        head()
                #prints the top n rows
        tail()
                #ptints the bottom n rows
